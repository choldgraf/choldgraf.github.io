# %% [markdown]
# # This is a test notebook
#
# Sidebar should work:

# %% [markdown]
# ## Here's a sidebar item
#
# does it work?

# %% [markdown]
# ## Wide-form should work too!
#
# Let's see

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.ion()

# %%
fig, ax = plt.subplots(figsize=(15, 5))
ax.plot(*np.random.randn(2, 100))
